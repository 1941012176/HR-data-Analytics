# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
student =  pd.read_csv(r"D:\CTTC files\Datasets for practice\Student_Performance.csv")
student
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
student.columns = ['Hours_Studied', 'Previous_score','Extracurricular_Activities','Sleep_hours', 'Sample_Paper', 'Performance_Index']
student
# Out:
#       Hours_Studied  Previous_score Extracurricular_Activities  Sleep_hours  \
# 0                 7              99                        Yes            9
# 1                 4              82                         No            4
# 2                 8              51                        Yes            7
# 3                 5              52                        Yes            5
# 4                 7              75                         No            8
# ...             ...             ...                        ...          ...
# 9995              1              49                        Yes            4
# 9996              7              64                        Yes            8
# 9997              6              83                        Yes            8
# 9998              9              97                        Yes            7
# 9999              7              74                         No            8
#
#       Sample_Paper  Performance_Index
# ...

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               10000 non-null  int64
#  1   Previous_score              10000 non-null  int64
#  2   Extracurricular_Activities  10000 non-null  object
#  3   Sleep_hours                 10000 non-null  int64
#  4   Sample_Paper                10000 non-null  int64
#  5   Performance_Index           10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
student.isnull().sum()
# Out:
# Hours_Studied                 0
# Previous_score                0
# Extracurricular_Activities    0
# Sleep_hours                   0
# Sample_Paper                  0
# Performance_Index             0
# dtype: int64

# %%
for i in student.columns:
    print(i, '\n', student[i].unique())
# Out:
# Hours_Studied
#  [7 4 8 5 3 6 2 1 9]
# Previous_score
#  [99 82 51 52 75 78 73 45 77 89 91 79 47 72 83 54 96 74 85 61 62 84 94 90
#  44 70 67 97 59 55 68 63 46 76 43 81 93 98 48 92 64 88 60 87 40 69 80 95
#  49 50 53 71 56 58 66 65 57 41 42 86]
# Extracurricular_Activities
#  ['Yes' 'No']
# Sleep_hours
#  [9 4 7 5 8 6]
# Sample_Paper
#  [1 2 5 6 0 8 3 4 9 7]
# Performance_Index
#  [ 91.  65.  45.  36.  66.  61.  63.  42.  69.  84.  73.  27.  33.  68.
#   43.  67.  70.  30.  71.  85.  57.  35.  49.  83.  74.  39.  58.  47.
#   60.  32.  64.  54.  17.  53.  75.  52.  78.  38.  98.  87.  41.  81.
#   15.  88.  95.  29.  21.  76.  25.  34.  50.  56.  82.  23.  46.  92.
#   77.  86.  44.  94.  40. 100.  31.  26.  18.  51.  72.  16.  28.  89.
#   48.  37.  62.  59.  19.  79.  22.  10.  90.  80.  24.  20.  96.  55.
#   97.  12.  93.  14.  99.  11.  13.]

# %%
student.describe(include='all')
# Out:
#         Hours_Studied  Previous_score Extracurricular_Activities  \
# count    10000.000000    10000.000000                      10000
# unique            NaN             NaN                          2
# top               NaN             NaN                         No
# freq              NaN             NaN                       5052
# mean         4.992900       69.445700                        NaN
# std          2.589309       17.343152                        NaN
# min          1.000000       40.000000                        NaN
# 25%          3.000000       54.000000                        NaN
# 50%          5.000000       69.000000                        NaN
# 75%          7.000000       85.000000                        NaN
# max          9.000000       99.000000                        NaN
#
#          Sleep_hours  Sample_Paper  Performance_Index
# count   10000.000000  10000.000000       10000.000000
# unique           NaN           NaN                NaN
# ...

# %%
plt.hist(student.Performance_Index)
plt.plot()
# Out:
# []

# %%
plt.bar(student.Hours_Studied[0:11],student.Performance_Index[0:11], width = 2)
plt.show()

# %%
plt.scatter(student.Hours_Studied,student.Performance_Index,s=60,marker='s',color = 'green')
plt.xlabel('Hours Studied')
plt.ylabel('Performance Index')
plt.show()

# %%
sns.boxplot(student.Performance_Index)
plt.show()

# %%
student.boxplot(column=['Hours_Studied', 'Previous_score', 'Sample_Paper'])
plt.show()

# %%
plt.scatter(student.Previous_score,student.Performance_Index,s=student['Sample_Paper']*10,alpha=0.5)

plt.show()

# %%
ip = student.drop(['Extracurricular_Activities'],axis = 1) 
op = student.Performance_Index

# %%
ip
# Out:
#       Hours_Studied  Previous_score  Sleep_hours  Sample_Paper  \
# 0                 7              99            9             1
# 1                 4              82            4             2
# 2                 8              51            7             2
# 3                 5              52            5             2
# 4                 7              75            8             5
# ...             ...             ...          ...           ...
# 9995              1              49            4             2
# 9996              7              64            8             5
# 9997              6              83            8             5
# 9998              9              97            7             0
# 9999              7              74            8             1
#
#       Performance_Index
# 0                  91.0
# 1                  65.0
# 2                  45.0
# 3                  36.0
# 4                  66.0
# ...                 ...
# 9995               23.0
# ...

# %%
op
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance_Index, Length: 10000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain , xtest, ytrain, ytest = train_test_split(ip,op,train_size=0.8)

# %%
xtrain
# Out:
#       Hours_Studied  Previous_score  Sleep_hours  Sample_Paper  \
# 1358              4              62            5             4
# 4419              6              46            4             5
# 4830              2              82            6             6
# 9557              3              62            6             2
# 3663              1              84            8             5
# ...             ...             ...          ...           ...
# 2219              2              61            9             9
# 2033              1              48            7             3
# 573               1              82            5             8
# 9338              2              87            7             6
# 5674              2              72            7             5
#
#       Performance_Index
# 1358               43.0
# 4419               31.0
# 4830               60.0
# 9557               40.0
# 3663               56.0
# ...                 ...
# 2219               37.0
# ...

# %%
ytrain
# Out:
# 1358    43.0
# 4419    31.0
# 4830    60.0
# 9557    40.0
# 3663    56.0
#         ...
# 2219    37.0
# 2033    19.0
# 573     59.0
# 9338    64.0
# 5674    50.0
# Name: Performance_Index, Length: 8000, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
sc = StandardScaler()
mimx = MinMaxScaler()

# %%
xtrain1 = sc.fit_transform(xtrain)
xtest1 = sc.fit_transform(xtest)

# %%
print(xtrain1[0:5])
print(xtrain[0:5])
# Out:
# [[-0.38173291 -0.42782829 -0.89506271 -0.20462799 -0.63349526]
#  [ 0.39198467 -1.35077332 -1.48493845  0.14412018 -1.25791049]
#  [-1.15545049  0.725853   -0.30518696  0.49286835  0.25109297]
#  [-0.7685917  -0.42782829 -0.30518696 -0.90212433 -0.78959907]
#  [-1.54230928  0.84122113  0.87456453  0.14412018  0.04295456]]
#       Hours_Studied  Previous_score  Sleep_hours  Sample_Paper  \
# 1358              4              62            5             4
# 4419              6              46            4             5
# 4830              2              82            6             6
# 9557              3              62            6             2
# 3663              1              84            8             5
#
#       Performance_Index
# 1358               43.0
# 4419               31.0
# 4830               60.0
# 9557               40.0
# 3663               56.0

# %%
xtrain2 = mimx.fit_transform(xtrain)
xtest2 = mimx.fit_transform(xtest)

# %%
print('Standard',xtrain1[0:5])
print('Normal',xtrain[0:5])
print('mimx',xtrain2[0:5])
# Out:
# Standard [[-0.38173291 -0.42782829 -0.89506271 -0.20462799 -0.63349526]
#  [ 0.39198467 -1.35077332 -1.48493845  0.14412018 -1.25791049]
#  [-1.15545049  0.725853   -0.30518696  0.49286835  0.25109297]
#  [-0.7685917  -0.42782829 -0.30518696 -0.90212433 -0.78959907]
#  [-1.54230928  0.84122113  0.87456453  0.14412018  0.04295456]]
# Normal       Hours_Studied  Previous_score  Sleep_hours  Sample_Paper  \
# 1358              4              62            5             4
# 4419              6              46            4             5
# 4830              2              82            6             6
# 9557              3              62            6             2
# 3663              1              84            8             5
#
#       Performance_Index
# 1358               43.0
# 4419               31.0
# 4830               60.0
# 9557               40.0
# 3663               56.0
# mimx [[0.375      0.37288136 0.2        0.44444444 0.35955056]
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(xtrain1, ytrain)
# Out:
# LinearRegression()

# %%
ypred = lr.predict(xtest1)

# %%
ytest.shape, ypred.shape
# Out:
# ((2000,), (2000,))

# %%
ypred
# Out:
# array([59.75642982, 80.79283697, 64.76509819, ..., 61.75989717,
#        46.73389206, 53.74602778])

# %%
ytest
# Out:
# 7665    60.0
# 4924    81.0
# 5164    65.0
# 6833    27.0
# 4666    28.0
#         ...
# 5631    37.0
# 8700    58.0
# 8063    62.0
# 7961    47.0
# 7200    54.0
# Name: Performance_Index, Length: 2000, dtype: float64

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
mse = mean_squared_error(ytest, ypred)
r2 = r2_score(ytest, ypred)
print('mean_Squared_Error=', mse, 'accuracy=', r2*100)
# Out:
# mean_Squared_Error= 0.06435848084376636 accuracy= 99.98251382566744

# %%
sns.lmplot(x='Sample_Paper', y='Performance_Index',data=student)
plt.title('Simple Linear Regression Plot')
plt.show()

# %%
sns.regplot(x = ytest, y= ypred,color='blue')
plt.show()

# %%
r2Score = r2_score(ytest,ypred)
print('Accuracy = ',round(r2Score,4)*100,'%')
mae_score = mean_absolute_error(ytest,ypred)
print('Mean Absolute Error = ',round(mae_score,4)*100,'%')
rmse_score = np.sqrt(mean_squared_error(ytest,ypred))
print('Root Mean Squared Error = ',round(rmse_score,4)*100,'%')
# Out:
# Accuracy =  99.98 %
# Mean Absolute Error =  25.15 %
# Root Mean Squared Error =  25.369999999999997 %

# %%
plt.scatter(ytest, ypred, color='blue')
plt.plot([min(ytest), max(ytest)], [min(ytest), max(ytest)], color='red', linewidth=2)
plt.xlabel('Actual Performance Index')
plt.ylabel('Predicted Performance Index')
plt.title('Actual vs Predicted Performance Index')
plt.show()
